# %%
# !pip install colab_ssh

# %%
# !pip install scipy

# %%
import subprocess

# Example: install a package using brew
subprocess.run(["brew", "install", "wget"])
# Out:
# ...
# To reinstall 1.25.0, run:
#   brew reinstall wget
# CompletedProcess(args=['brew', 'install', 'wget'], returncode=0)

# %%
import apt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import apt
#
# ModuleNotFoundError: No module named 'apt'

# %%
from colab_ssh import launch_ssh
launch_ssh("aman3569kumar@gmail.com", "What@12345")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from colab_ssh import launch_ssh
#       2 launch_ssh("aman3569kumar@gmail.com", "What@12345")
#
# File ~/anaconda3/envs/travelgpt/lib/python3.11/site-packages/colab_ssh/__init__.py:8
#       6 from colab_ssh.set_private_key import set_private_key
#       7 from colab_ssh.get_tunnel_config import get_tunnel_config
# ----> 8 from colab_ssh.launch_ssh_cloudflared import launch_ssh_cloudflared
#      10 __all__ = [
#      11     "launch_ssh",
#      12     "init_git",
#    (...)     19     "launch_ssh_cloudflared",
#      20 ]
#
# File ~/anaconda3/envs/travelgpt/lib/python3.11/site-packages/colab_ssh/launch_ssh_cloudflared.py:1
# ----> 1 from colab_ssh.utils.packages.installer import create_deb_installer
#       2 from colab_ssh.utils.ui.render_html import render_template
# ...

# %%
python3 -c "import apt"
# Out:
#   Cell In[5], line 1
#     python3 -c "import apt"
#                ^
# SyntaxError: invalid syntax
